# %% [markdown]
# 1. Create a function that takes three integer arguments (a, b, c) and returns the amount of integers which are of equal value.

# %%
num1 = int(input("Enter the first integer: "))
num2 = int(input("Enter the second integer: "))
num3 = int(input("Enter the third integer: "))
def equal(a,b,c):
    if a==b and a==c and b==c:
        return 3
    elif b==a or b==c:
        return 2
    elif c==a or c==b:
        return 2
    elif a==b or a==c:
        return 2
    else:
        return 0
    
equal(num1, num2, num3)
# Out:
# Enter the first integer: 1
# Enter the second integer: 2
# Enter the third integer: 2
# 2

# %% [markdown]
# 2. Write a function that converts a dictionary into a list of keys-values tuples.

# %%
pair_num = int(input("Enter the number of key and values you want in dictionary: "))
d = {}
for i in range(pair_num):
    key = input("Enter the Key (String): ")
    value = int(input("Enter the Value (integer): "))
    d[key] = value
    
print(d)

def dict_to_tuples(**kwargs):
    l= list(d.items())
    return l
dict_to_tuples()
# Out:
# Enter the number of key and values you want in dictionary: 2
# Enter the Key (String): j
# Enter the Value (integer): 20
# Enter the Key (String): p
# Enter the Value (integer): 23
# {'j': 20, 'p': 23}
# [('j', 20), ('p', 23)]

# %% [markdown]
# 3. Write a function that creates a dictionary with each (key, value) pair being the (lower case, upper case) versions of a letter, respectively.

# %%
def lower_upper(*a):
    pair_num = int(input("Enter the number of key and values you want in dictionary: "))
    d = {}
    for i in range(pair_num):
        key = input("Enter the Key: ").lower()
        value = key.upper()
        d[key] = value

    return d

lower_upper()
# Out:
# Enter the number of key and values you want in dictionary: 5
# Enter the Key: Prithvi
# Enter the Key: BiSWAS
# Enter the Key: SHREYA
# Enter the Key: PATIL
# Enter the Key: PURNa
# {'prithvi': 'PRITHVI',
#  'biswas': 'BISWAS',
#  'shreya': 'SHREYA',
#  'patil': 'PATIL',
#  'purna': 'PURNA'}

# %% [markdown]
# 4. Write a function, that replaces all vowels in a string with a specified vowel.

# %%
def vowel(*a):
    string = input("Enter the string: ")
    new_char = input("Enter the character you want replace with: ")
    new_string = ""
    for char in string:
        lower_char = char.lower()
        if lower_char == "a" or lower_char == "e" or lower_char == "i" or lower_char == "o" or lower_char == "u":
            new_string += new_char
        else:
            new_string += char
    return new_string
vowel()
# Out:
# Enter the string: biswas
# Enter the character you want replace with: *
# 'b*sw*s'

# %% [markdown]
# 5. Create a function that takes a string as input and capitalizes a letter if its ASCII code is even and returns its lower case version if its ASCII code is odd.

# %%
def ascii_capitalize(*a):
    string = input("Enter the string: ")
    new_string = ""
    for char in string:
        if ord(char)%2==0:
            new_string += char.upper()
        else:
            new_string += char.lower()
    return new_string
ascii_capitalize()
# Out:
# Enter the string: to be or not to be
# 'To Be oR NoT To Be'
