# %% [markdown]
# 1. Create a function that takes an integer and returns a list from 1 to the given number, where:
# (a) If the number can be divided evenly by 4, amplify it by 10 (i.e. return 10 times the number).
# (b) If the number cannot be divided evenly by 4, simply return the number.

# %%
limit = int(input("Enter the upper limit to which you want amplify: "))
def amplify(a):
    l=[]
    for i in range(1,limit+1):
        if i%4==0:
            s = i*10
            l.append(s)
        else:
            l.append(i)
    return l
amplify(limit)
# Out:
# Enter the upper limit to which you want amplify: 25
# [1,
#  2,
#  3,
#  40,
#  5,
#  6,
#  7,
#  80,
#  9,
#  10,
#  11,
#  120,
#  13,
#  14,
#  15,
#  160,
#  17,
#  18,
#  19,
#  200,
#  21,
#  22,
#  23,
#  240,
#  25]

# %% [markdown]
# 2. Create a function that takes a list of numbers and return the number that's unique.

# %%
index = int(input('Enter the number of index you want to have: '))
l = []
for i in range(index):
    value = float(input('Enter the number to find the unique: '))
    l.append(value)
print(l)  

def unique(l):
    for i in range(0,len(l)-1):
        if l[i] == l[i+1]:
            pass
        else:
            return (f"The unique element in the list is {l[i+1]}")
        
unique(l)
# Out:
# Enter the number of index you want to have: 6
# Enter the number to find the unique: 0
# Enter the number to find the unique: 0
# Enter the number to find the unique: 0.77
# Enter the number to find the unique: 0
# Enter the number to find the unique: 0
# Enter the number to find the unique: 0
# [0.0, 0.0, 0.77, 0.0, 0.0, 0.0]
# 'The unique element in the list is 0.77'

# %% [markdown]
# 3. Your task is to create a Circle constructor that creates a circle with a radius provided by an argument. The circles constructed must have two getters getArea() (PIr^2) and getPerimeter() (2PI*r) which give both respective areas and perimeter (circumference).

# %%
radius = float(input("Enter the radius of a circle: "))
def circle(r):
    getArea = 3.14*radius*radius
    getPerimeter = 2*3.14*radius

    return getArea, getPerimeter

circle(radius)
# Out:
# Enter the radius of a circle: 4.44
# (61.90070400000001, 27.883200000000002)

# %% [markdown]
# 4. Create a function that takes a list of strings and return a list, sorted from shortest to longest.

# %%
index = int(input('Enter the number of index you want to have: '))
l = []
for i in range(index):
    string = input('Enter the string to be sorted: ')
    l.append(string)
print(l)

def sort_by_string(l):
    l.sort(key=len)
    return l

sort_by_string(l)
# Out:
# Enter the number of index you want to have: 3
# Enter the number to find the unique: mcirosoft
# Enter the number to find the unique: apple
# Enter the number to find the unique: google
# ['mcirosoft', 'apple', 'google']
# ['apple', 'google', 'mcirosoft']

# %% [markdown]
# 5. Create a function that validates whether three given integers form a Pythagorean triplet. The sum of the squares of the two smallest integers must equal the square of the largest number to
# be validated.

# %%
l = []
for i in range(3):
    number = int(input('Enter: '))
    l.append(number)
    l.sort()
print(l)

def is_triplet(a):
    if ((l[0]**2) + (l[1]**2)) == l[2]**2:
        return "The given numbers are Pythagorean triplet."
    else:
        return "They are not Pythagorean triplet" 
is_triplet(l)
# Out:
# Enter: 5
# Enter: 4
# Enter: 2
# [2, 4, 5]
# 'They are not Pythagorean triplet'
